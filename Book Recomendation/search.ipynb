# %%
conda install m2-base
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\lilil\anaconda3
#
#   added / updated specs:
#     - m2-base
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py39haa95532_0         149 KB
#     conda-22.11.1              |   py39haa95532_4         892 KB
#     m2-base-1.0.0              |                3         178 KB
#     m2-bash-4.3.042            |                5         3.5 MB
#     m2-bash-completion-2.3     |                2         187 KB
#     m2-catgets-1.1             |                3          26 KB
#     m2-coreutils-8.25          |              102         4.7 MB
#     m2-dash-0.5.8              |                2          94 KB
#     m2-file-5.25               |                2         792 KB
#     m2-filesystem-2016.04      |                4          26 KB
#     m2-findutils-4.6.0         |                2         635 KB
#     m2-gawk-4.1.3              |                2         1.5 MB
#     m2-gcc-libs-5.3.0          |                4        1021 KB
#     m2-gettext-0.19.7          |                4         2.0 MB
#     m2-gmp-6.1.0               |                3         407 KB
#     m2-grep-2.22               |                4         259 KB
#     m2-gzip-1.7                |                2         102 KB
#     m2-inetutils-1.9.2         |                2         309 KB
#     m2-info-6.0                |                2         237 KB
#     m2-less-481                |                2         105 KB
#     m2-libasprintf-0.19.7      |                4           6 KB
#     m2-libcatgets-1.1          |                3           7 KB
#     m2-libcrypt-1.3            |                2           7 KB
#     m2-libgettextpo-0.19.7     |                4         124 KB
#     m2-libiconv-1.14           |                3         716 KB
#     m2-libintl-0.19.7          |                4          22 KB
#     m2-liblzma-5.2.2           |                2          78 KB
#     m2-libpcre-8.38            |                2          98 KB
#     m2-libreadline-6.3.008     |                8         275 KB
#     m2-libutil-linux-2.26.2    |                2         224 KB
#     m2-libxml2-2.9.2           |                3         562 KB
#     m2-mintty-1!2.2.3          |                2         170 KB
#     m2-mpfr-3.1.4              |                2         254 KB
#     m2-msys2-launcher-git-0.3.28.860c495|                2          27 KB
#     m2-ncurses-6.0.20160220    |                2         1.4 MB
#     m2-sed-4.2.2               |                3         846 KB
#     m2-tftp-hpa-5.2            |                2          21 KB
#     m2-time-1.7                |                2          18 KB
#     m2-ttyrec-1.0.8            |                2          13 KB
#     m2-tzcode-2015.e           |                2         379 KB
#     m2-util-linux-2.26.2       |                2         1.7 MB
#     m2-which-2.21              |                3          21 KB
#     m2-zlib-1.2.8              |                4          51 KB
#     ruamel.yaml-0.17.21        |   py39h2bbff1b_0         174 KB
#     ruamel.yaml.clib-0.2.6     |   py39h2bbff1b_1         101 KB
#     ------------------------------------------------------------
#                                            Total:        24.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   m2-base            pkgs/msys2/win-64::m2-base-1.0.0-3 None
#   m2-bash            pkgs/msys2/win-64::m2-bash-4.3.042-5 None
#   m2-bash-completion pkgs/msys2/win-64::m2-bash-completion-2.3-2 None
#   m2-catgets         pkgs/msys2/win-64::m2-catgets-1.1-3 None
#   m2-coreutils       pkgs/msys2/win-64::m2-coreutils-8.25-102 None
#   m2-dash            pkgs/msys2/win-64::m2-dash-0.5.8-2 None
#   m2-file            pkgs/msys2/win-64::m2-file-5.25-2 None
#   m2-filesystem      pkgs/msys2/win-64::m2-filesystem-2016.04-4 None
#   m2-findutils       pkgs/msys2/win-64::m2-findutils-4.6.0-2 None
#   m2-gawk            pkgs/msys2/win-64::m2-gawk-4.1.3-2 None
#   m2-gcc-libs        pkgs/msys2/win-64::m2-gcc-libs-5.3.0-4 None
#   m2-gettext         pkgs/msys2/win-64::m2-gettext-0.19.7-4 None
#   m2-gmp             pkgs/msys2/win-64::m2-gmp-6.1.0-3 None
#   m2-grep            pkgs/msys2/win-64::m2-grep-2.22-4 None
#   m2-gzip            pkgs/msys2/win-64::m2-gzip-1.7-2 None
#   m2-inetutils       pkgs/msys2/win-64::m2-inetutils-1.9.2-2 None
#   m2-info            pkgs/msys2/win-64::m2-info-6.0-2 None
#   m2-less            pkgs/msys2/win-64::m2-less-481-2 None
#   m2-libasprintf     pkgs/msys2/win-64::m2-libasprintf-0.19.7-4 None
#   m2-libcatgets      pkgs/msys2/win-64::m2-libcatgets-1.1-3 None
#   m2-libcrypt        pkgs/msys2/win-64::m2-libcrypt-1.3-2 None
#   m2-libgettextpo    pkgs/msys2/win-64::m2-libgettextpo-0.19.7-4 None
#   m2-libiconv        pkgs/msys2/win-64::m2-libiconv-1.14-3 None
#   m2-libintl         pkgs/msys2/win-64::m2-libintl-0.19.7-4 None
#   m2-liblzma         pkgs/msys2/win-64::m2-liblzma-5.2.2-2 None
#   m2-libpcre         pkgs/msys2/win-64::m2-libpcre-8.38-2 None
#   m2-libreadline     pkgs/msys2/win-64::m2-libreadline-6.3.008-8 None
#   m2-libutil-linux   pkgs/msys2/win-64::m2-libutil-linux-2.26.2-2 None
#   m2-libxml2         pkgs/msys2/win-64::m2-libxml2-2.9.2-3 None
#   m2-mintty          pkgs/msys2/win-64::m2-mintty-1!2.2.3-2 None
#   m2-mpfr            pkgs/msys2/win-64::m2-mpfr-3.1.4-2 None
#   m2-msys2-launcher~ pkgs/msys2/win-64::m2-msys2-launcher-git-0.3.28.860c495-2 None
#   m2-ncurses         pkgs/msys2/win-64::m2-ncurses-6.0.20160220-2 None
#   m2-sed             pkgs/msys2/win-64::m2-sed-4.2.2-3 None
#   m2-tftp-hpa        pkgs/msys2/win-64::m2-tftp-hpa-5.2-2 None
#   m2-time            pkgs/msys2/win-64::m2-time-1.7-2 None
#   m2-ttyrec          pkgs/msys2/win-64::m2-ttyrec-1.0.8-2 None
#   m2-tzcode          pkgs/msys2/win-64::m2-tzcode-2015.e-2 None
#   m2-util-linux      pkgs/msys2/win-64::m2-util-linux-2.26.2-2 None
#   m2-which           pkgs/msys2/win-64::m2-which-2.21-3 None
#   m2-zlib            pkgs/msys2/win-64::m2-zlib-1.2.8-4 None
#   ruamel.yaml        pkgs/main/win-64::ruamel.yaml-0.17.21-py39h2bbff1b_0 None
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py39h2bbff1b_1 None
#
# The following packages will be UPDATED:
#
#   certifi                          2022.9.24-py39haa95532_0 --> 2022.12.7-py39haa95532_0 None
#   conda                               22.9.0-py39haa95532_0 --> 22.11.1-py39haa95532_4 None
#
#
#
# Downloading and Extracting Packages
#
# m2-libcrypt-1.3      | 7 KB      |            |   0%
# m2-libcrypt-1.3      | 7 KB      | ########## | 100%
# m2-libcrypt-1.3      | 7 KB      | ########## | 100%
#
# m2-coreutils-8.25    | 4.7 MB    |            |   0%
# m2-coreutils-8.25    | 4.7 MB    | #8         |  18%
# m2-coreutils-8.25    | 4.7 MB    | ########7  |  88%
# m2-coreutils-8.25    | 4.7 MB    | ########## | 100%
#
# m2-libgettextpo-0.19 | 124 KB    |            |   0%
# m2-libgettextpo-0.19 | 124 KB    | ########## | 100%
# m2-libgettextpo-0.19 | 124 KB    | ########## | 100%
#
# m2-base-1.0.0        | 178 KB    |            |   0%
# m2-base-1.0.0        | 178 KB    | ########## | 100%
#
# m2-mpfr-3.1.4        | 254 KB    |            |   0%
# m2-mpfr-3.1.4        | 254 KB    | ########## | 100%
# m2-mpfr-3.1.4        | 254 KB    | ########## | 100%
#
# m2-time-1.7          | 18 KB     |            |   0%
# m2-time-1.7          | 18 KB     | ########## | 100%
#
# m2-dash-0.5.8        | 94 KB     |            |   0%
# m2-dash-0.5.8        | 94 KB     | ########## | 100%
#
# m2-gmp-6.1.0         | 407 KB    |            |   0%
# m2-gmp-6.1.0         | 407 KB    | ########## | 100%
# m2-gmp-6.1.0         | 407 KB    | ########## | 100%
#
# m2-bash-4.3.042      | 3.5 MB    |            |   0%
# m2-bash-4.3.042      | 3.5 MB    | ######2    |  63%
# m2-bash-4.3.042      | 3.5 MB    | ########## | 100%
#
# m2-gzip-1.7          | 102 KB    |            |   0%
# m2-gzip-1.7          | 102 KB    | ########## | 100%
#
# m2-libcatgets-1.1    | 7 KB      |            |   0%
# m2-libcatgets-1.1    | 7 KB      | ########## | 100%
#
# m2-libxml2-2.9.2     | 562 KB    |            |   0%
# m2-libxml2-2.9.2     | 562 KB    | ########## | 100%
# m2-libxml2-2.9.2     | 562 KB    | ########## | 100%
#
# m2-gettext-0.19.7    | 2.0 MB    |            |   0%
# m2-gettext-0.19.7    | 2.0 MB    | #####2     |  53%
# m2-gettext-0.19.7    | 2.0 MB    | ########## | 100%
#
# conda-22.11.1        | 892 KB    |            |   0%
# conda-22.11.1        | 892 KB    | ########## | 100%
# conda-22.11.1        | 892 KB    | ########## | 100%
#
# m2-bash-completion-2 | 187 KB    |            |   0%
# m2-bash-completion-2 | 187 KB    | ########## | 100%
# m2-bash-completion-2 | 187 KB    | ########## | 100%
#
# certifi-2022.12.7    | 149 KB    |            |   0%
# certifi-2022.12.7    | 149 KB    | ########## | 100%
#
# m2-tzcode-2015.e     | 379 KB    |            |   0%
# m2-tzcode-2015.e     | 379 KB    | ########## | 100%
# m2-tzcode-2015.e     | 379 KB    | ########## | 100%
#
# m2-findutils-4.6.0   | 635 KB    |            |   0%
# m2-findutils-4.6.0   | 635 KB    | ########## | 100%
# m2-findutils-4.6.0   | 635 KB    | ########## | 100%
#
# m2-file-5.25         | 792 KB    |            |   0%
# m2-file-5.25         | 792 KB    | ########## | 100%
# m2-file-5.25         | 792 KB    | ########## | 100%
#
# m2-inetutils-1.9.2   | 309 KB    |            |   0%
# m2-inetutils-1.9.2   | 309 KB    | ########## | 100%
# m2-inetutils-1.9.2   | 309 KB    | ########## | 100%
#
# m2-info-6.0          | 237 KB    |            |   0%
# m2-info-6.0          | 237 KB    | ########## | 100%
#
# m2-gawk-4.1.3        | 1.5 MB    |            |   0%
# m2-gawk-4.1.3        | 1.5 MB    | ########## | 100%
# m2-gawk-4.1.3        | 1.5 MB    | ########## | 100%
#
# m2-tftp-hpa-5.2      | 21 KB     |            |   0%
# m2-tftp-hpa-5.2      | 21 KB     | ########## | 100%
#
# m2-libreadline-6.3.0 | 275 KB    |            |   0%
# m2-libreadline-6.3.0 | 275 KB    | ########## | 100%
# m2-libreadline-6.3.0 | 275 KB    | ########## | 100%
#
# m2-gcc-libs-5.3.0    | 1021 KB   |            |   0%
# m2-gcc-libs-5.3.0    | 1021 KB   | ########## | 100%
# m2-gcc-libs-5.3.0    | 1021 KB   | ########## | 100%
#
# m2-mintty-1!2.2.3    | 170 KB    |            |   0%
# m2-mintty-1!2.2.3    | 170 KB    | ########## | 100%
#
# ruamel.yaml-0.17.21  | 174 KB    |            |   0%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
#
# m2-util-linux-2.26.2 | 1.7 MB    |            |   0%
# m2-util-linux-2.26.2 | 1.7 MB    | ########## | 100%
# m2-util-linux-2.26.2 | 1.7 MB    | ########## | 100%
#
# m2-libutil-linux-2.2 | 224 KB    |            |   0%
# m2-libutil-linux-2.2 | 224 KB    | ########## | 100%
#
# m2-filesystem-2016.0 | 26 KB     |            |   0%
# m2-filesystem-2016.0 | 26 KB     | ########## | 100%
#
# m2-msys2-launcher-gi | 27 KB     |            |   0%
# m2-msys2-launcher-gi | 27 KB     | ########## | 100%
#
# m2-libiconv-1.14     | 716 KB    |            |   0%
# m2-libiconv-1.14     | 716 KB    | #########6 |  96%
# m2-libiconv-1.14     | 716 KB    | ########## | 100%
#
# m2-zlib-1.2.8        | 51 KB     |            |   0%
# m2-zlib-1.2.8        | 51 KB     | ########## | 100%
#
# m2-libasprintf-0.19. | 6 KB      |            |   0%
# m2-libasprintf-0.19. | 6 KB      | ########## | 100%
#
# m2-sed-4.2.2         | 846 KB    |            |   0%
# m2-sed-4.2.2         | 846 KB    | ########## | 100%
# m2-sed-4.2.2         | 846 KB    | ########## | 100%
#
# m2-less-481          | 105 KB    |            |   0%
# m2-less-481          | 105 KB    | ########## | 100%
#
# m2-ttyrec-1.0.8      | 13 KB     |            |   0%
# m2-ttyrec-1.0.8      | 13 KB     | ########## | 100%
#
# ruamel.yaml.clib-0.2 | 101 KB    |            |   0%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
#
# m2-liblzma-5.2.2     | 78 KB     |            |   0%
# m2-liblzma-5.2.2     | 78 KB     | ########## | 100%
#
# m2-libintl-0.19.7    | 22 KB     |            |   0%
# m2-libintl-0.19.7    | 22 KB     | ########## | 100%
#
# m2-grep-2.22         | 259 KB    |            |   0%
# m2-grep-2.22         | 259 KB    | ########## | 100%
# m2-grep-2.22         | 259 KB    | ########## | 100%
#
# m2-catgets-1.1       | 26 KB     |            |   0%
# m2-catgets-1.1       | 26 KB     | ########## | 100%
#
# m2-which-2.21        | 21 KB     |            |   0%
# m2-which-2.21        | 21 KB     | ########## | 100%
#
# m2-ncurses-6.0.20160 | 1.4 MB    |            |   0%
# m2-ncurses-6.0.20160 | 1.4 MB    | ########## | 100%
# m2-ncurses-6.0.20160 | 1.4 MB    | ########## | 100%
#
# m2-libpcre-8.38      | 98 KB     |            |   0%
# m2-libpcre-8.38      | 98 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wc -l goodreads_books.json.gz
# Out:
# 7588375 goodreads_books.json.gz

# %%
# !ls -lh | grep goodreads_books.json.gz
# Out:
# -rw-r--r-- 1 lilil lilil 2.0G Jan 13 14:06 goodreads_books.json.gz

# %%
import gzip

# %%
with gzip.open('goodreads_books.json.gz') as f:
    line = f.readline()

# %%
line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %%
import json

# %%
data  = json.loads(line)
data
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
def parse_fields(line):
    data = json.loads(line)
    return {
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image": data["image_url"]
    }

# %%
books_titles = []
with gzip.open('goodreads_books.json.gz', 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        fields = parse_fields(line)
        
        try:
            ratings = int(fields['ratings'])
        except ValueError:
            continue
        if ratings > 15:
            books_titles.append(fields)

# %%
import pandas as pd
titles = pd.DataFrame.from_dict(books_titles)

# %%
titles['ratings'] = pd.to_numeric(titles['ratings'])

# %%
titles['mod_title'] = titles['title'].str.replace('[^a-zA-Z0-9 ]', '', regex = True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          The Unschooled Wizard Sun Wolf and Starhawk 12
# 1                                    Best Friends Forever
# 2                           The Aeneid for Boys and Girls
# 3        Alls Fairy in Love and War Avalon Web of Magic 8
# 4                                     The Devils Notebook
# ...                                                   ...
# 1308952                          Ondine Ondine Quartet 05
# 1308953     Jacqueline Kennedy Onassis Friend of the Arts
# 1308954                   The Spaniards Blackmailed Bride
# 1308955           The Childrens Classic Poetry Collection
# 1308956               101 Nights Volume One 101 Nights 13
#
# [1308957 rows x 6 columns]

# %%
titles['mod_title'] = titles['mod_title'].str.lower()

# %%
titles['mod_title'] = titles['mod_title'].str.replace("\s+"," ", regex=True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1308957 rows x 6 columns]

# %%
titles = titles[titles['mod_title'].str.len()>0]

# %%
titles.to_json('books_titles.json')

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1302659 rows x 6 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles['mod_title'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

def search(query, vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    return results.head(5).style.format({'url': make_clickable, 'cover_image': show_image})

# %%
search("the living goddesses", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fab0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fab0e_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_fab0e_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_fab0e_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_fab0e_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_fab0e_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_fab0e_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab0e_level0_row0" class="row_heading level0 row0" >685841</th>
#       <td id="T_fab0e_row0_col0" class="data row0 col0" >32969045</td>
#       <td id="T_fab0e_row0_col1" class="data row0 col1" >The Goddesses</td>
#       <td id="T_fab0e_row0_col2" class="data row0 col2" >574</td>
#       <td id="T_fab0e_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/32969045-the-goddesses">Goodreads</a></td>
#       <td id="T_fab0e_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1485544442m/32969045.jpg" width=50></img></td>
#       <td id="T_fab0e_row0_col5" class="data row0 col5" >the goddesses</td>
#     </tr>
#     <tr>
#       <th id="T_fab0e_level0_row1" class="row_heading level0 row1" >1114428</th>
#       <td id="T_fab0e_row1_col0" class="data row1 col0" >226524</td>
#       <td id="T_fab0e_row1_col1" class="data row1 col1" >Goddesses  Angels</td>
#       <td id="T_fab0e_row1_col2" class="data row1 col2" >354</td>
#       <td id="T_fab0e_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/226524.Goddesses_Angels">Goodreads</a></td>
#       <td id="T_fab0e_row1_col4" class="data row1 col4" ><img src="https://images.gr-assets.com/books/1328860539m/226524.jpg" width=50></img></td>
#       <td id="T_fab0e_row1_col5" class="data row1 col5" >goddesses angels</td>
#     </tr>
#     <tr>
#       <th id="T_fab0e_level0_row2" class="row_heading level0 row2" >802229</th>
#       <td id="T_fab0e_row2_col0" class="data row2 col0" >226535</td>
#       <td id="T_fab0e_row2_col1" class="data row2 col1" >The Book of Goddesses</td>
#       <td id="T_fab0e_row2_col2" class="data row2 col2" >162</td>
#       <td id="T_fab0e_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/226535.The_Book_of_Goddesses">Goodreads</a></td>
#       <td id="T_fab0e_row2_col4" class="data row2 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_fab0e_row2_col5" class="data row2 col5" >the book of goddesses</td>
#     </tr>
#     <tr>
#       <th id="T_fab0e_level0_row3" class="row_heading level0 row3" >454642</th>
#       <td id="T_fab0e_row3_col0" class="data row3 col0" >897906</td>
#       <td id="T_fab0e_row3_col1" class="data row3 col1" >The Living Goddesses</td>
#       <td id="T_fab0e_row3_col2" class="data row3 col2" >115</td>
#       <td id="T_fab0e_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/897906.The_Living_Goddesses">Goodreads</a></td>
#       <td id="T_fab0e_row3_col4" class="data row3 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_fab0e_row3_col5" class="data row3 col5" >the living goddesses</td>
#     </tr>
#     <tr>
#       <th id="T_fab0e_level0_row4" class="row_heading level0 row4" >1086557</th>
#       <td id="T_fab0e_row4_col0" class="data row4 col0" >15710353</td>
#       <td id="T_fab0e_row4_col1" class="data row4 col1" >American Goddesses</td>
#       <td id="T_fab0e_row4_col2" class="data row4 col2" >71</td>
#       <td id="T_fab0e_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/15710353-american-goddesses">Goodreads</a></td>
#       <td id="T_fab0e_row4_col4" class="data row4 col4" ><img src="https://images.gr-assets.com/books/1339970446m/15710353.jpg" width=50></img></td>
#       <td id="T_fab0e_row4_col5" class="data row4 col5" >american goddesses</td>
#     </tr>
#   </tbody>
# </table>

# %%
liked_books = ['910444','470368', '226527','17021','5960325','11103382','1271159','3869','31296835','897906']
