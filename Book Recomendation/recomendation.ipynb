# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping={}
with open('book_id_map.csv') as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id]=book_id

# %%
len(csv_book_mapping)
# Out:
# 2360651

# %%
# !wc -l goodreads_interactions.csv
# Out:
# 228648343 goodreads_interactions.csv

# %%
# !ls -lh | grep goodreads_interactions.csv
# Out:
# -rw-r--r-- 1 lilil lilil 4.1G Jan 13 14:04 goodreads_interactions.csv

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
liked_books = ['910444','470368', '226527','17021','5960325','11103382','1271159','3869','31296835','897906']
# liked_books = ["4408", "31147619", "29983711", "9401317", "9317691", "8153988", "20494944"]

# %%
overlap_users = set()

with open('goodreads_interactions.csv','r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _=line.split(',')
        
        if user_id in overlap_users:
            continue
        
        try:
            rating = int(rating)
        except ValueError:
            continue
            
        book_id  = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating>4:
            overlap_users.add(user_id)

# %%
rec_lines = []
with open('goodreads_interactions.csv','r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id,_, rating, _ = line.split(',')

        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
import pandas as pd

recs = pd.DataFrame(rec_lines, columns = ["user_id","book_id","rating"])
recs['book_id'] = recs['book_id'].astype(str)

# %%
top_recs = recs['book_id'].value_counts().head(10)
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json('books_titles.json')
books_titles['book_id'] = books_titles['book_id'].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
books_titles[books_titles['book_id'].isin(top_recs)]
# Out:
#          book_id                                              title  ratings  \
# 284473   2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 401395      5107                             The Catcher in the Rye  2086945
# 446972      5907                                         The Hobbit  2099680
# 463463      4671                                   The Great Gatsby  2758812
# 615314      5470                                               1984  2023937
# 770177      7613                                        Animal Farm  1928931
# 790927      2657                              To Kill a Mockingbird  3255518
# 878545         3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 958091      3869                            A Brief History of Time   173373
# 1258258    48855                          The Diary of a Young Girl  2028299
#
#                                                        url  \
# 284473   https://www.goodreads.com/book/show/2767052-th...
# 401395   https://www.goodreads.com/book/show/5107.The_C...
# 446972   https://www.goodreads.com/book/show/5907.The_H...
# 463463   https://www.goodreads.com/book/show/4671.The_G...
# 615314       https://www.goodreads.com/book/show/5470.1984
# 770177   https://www.goodreads.com/book/show/7613.Anima...
# 790927   https://www.goodreads.com/book/show/2657.To_Ki...
# 878545   https://www.goodreads.com/book/show/3.Harry_Po...
# 958091   https://www.goodreads.com/book/show/3869.A_Bri...
# 1258258  https://www.goodreads.com/book/show/48855.The_...
#
#                                                cover_image  \
# 284473   https://images.gr-assets.com/books/1447303603m...
# 401395   https://images.gr-assets.com/books/1398034300m...
# 446972   https://images.gr-assets.com/books/1372847500m...
# 463463   https://images.gr-assets.com/books/1490528560m...
# 615314   https://images.gr-assets.com/books/1348990566m...
# 770177   https://images.gr-assets.com/books/1424037542m...
# 790927   https://images.gr-assets.com/books/1361975680m...
# 878545   https://images.gr-assets.com/books/1474154022m...
# 958091   https://images.gr-assets.com/books/1333578746m...
# 1258258  https://images.gr-assets.com/books/1358276407m...
#
#                                                  mod_title
# 284473                 the hunger games the hunger games 1
# 401395                              the catcher in the rye
# 446972                                          the hobbit
# 463463                                    the great gatsby
# 615314                                                1984
# 770177                                         animal farm
# 790927                               to kill a mockingbird
# 878545   harry potter and the sorcerers stone harry pot...
# 958091                             a brief history of time
# 1258258                          the diary of a young girl

# %%
all_recs = recs['book_id'].value_counts()

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ['book_id', 'book_count']

# %%
all_recs.head()
# Out:
#   book_id  book_count
# 0    3869        4453
# 1    5470        3197
# 2    2657        3135
# 3       3        2994
# 4    4671        2851

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs['score']=all_recs['book_count'] * (all_recs['book_count']/all_recs['ratings'])

# %%
all_recs.head()
# Out:
#   book_id  book_count                                              title  \
# 0    3869        4453                            A Brief History of Time
# 1    5470        3197                                               1984
# 2    2657        3135                              To Kill a Mockingbird
# 3       3        2994  Harry Potter and the Sorcerer's Stone (Harry P...
# 4    4671        2851                                   The Great Gatsby
#
#    ratings                                                url  \
# 0   173373  https://www.goodreads.com/book/show/3869.A_Bri...
# 1  2023937      https://www.goodreads.com/book/show/5470.1984
# 2  3255518  https://www.goodreads.com/book/show/2657.To_Ki...
# 3  4765497  https://www.goodreads.com/book/show/3.Harry_Po...
# 4  2758812  https://www.goodreads.com/book/show/4671.The_G...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1333578746m...
# 1  https://images.gr-assets.com/books/1348990566m...
# 2  https://images.gr-assets.com/books/1361975680m...
# 3  https://images.gr-assets.com/books/1474154022m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                            mod_title       score
# 0                            a brief history of time  114.373109
# 1                                               1984    5.049964
# 2                              to kill a mockingbird    3.018944
# 3  harry potter and the sorcerers stone harry pot...    1.881029
# 4                                   the great gatsby    2.946269

# %%
all_recs.sort_values('score', ascending=False).head(10)
# Out:
#         book_id  book_count                                title  ratings  \
# 0          3869        4453              A Brief History of Time   173373
# 7392   34927828          56                      The Great Alone       70
# 36      5960325        1743   Shanghai Girls (Shanghai Girls #1)   108206
# 58        55030        1449                               Cosmos    79680
# 125     8520362        1030                     The Grand Design    44203
# 247        2095         742           The Universe in a Nutshell    24029
# 135     9500416        1006    Dreams of Joy (Shanghai Girls #2)    44570
# 16246   8514123          27                 All the Talk Is Dead       35
# 1613   11790127         196          All the Flowers in Shanghai     1849
# 10068  28335696          42  Persepolis Rising (The Expanse, #7)       89
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/3869.A_Bri...
# 7392   https://www.goodreads.com/book/show/34927828-t...
# 36     https://www.goodreads.com/book/show/5960325-sh...
# 58      https://www.goodreads.com/book/show/55030.Cosmos
# 125    https://www.goodreads.com/book/show/8520362-th...
# 247    https://www.goodreads.com/book/show/2095.The_U...
# 135    https://www.goodreads.com/book/show/9500416-dr...
# 16246  https://www.goodreads.com/book/show/8514123-al...
# 1613   https://www.goodreads.com/book/show/11790127-a...
# 10068  https://www.goodreads.com/book/show/28335696-p...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1333578746m...
# 7392   https://images.gr-assets.com/books/1501852384m...
# 36     https://images.gr-assets.com/books/1327968416m...
# 58     https://s.gr-assets.com/assets/nophoto/book/11...
# 125    https://images.gr-assets.com/books/1320558363m...
# 247    https://images.gr-assets.com/books/1159814395m...
# 135    https://s.gr-assets.com/assets/nophoto/book/11...
# 16246  https://s.gr-assets.com/assets/nophoto/book/11...
# 1613   https://images.gr-assets.com/books/1316294492m...
# 10068  https://images.gr-assets.com/books/1481562381m...
#
#                              mod_title       score
# 0              a brief history of time  114.373109
# 7392                   the great alone   44.800000
# 36     shanghai girls shanghai girls 1   28.076530
# 58                              cosmos   26.350414
# 125                   the grand design   24.000633
# 247         the universe in a nutshell   22.912481
# 135     dreams of joy shanghai girls 2   22.706664
# 16246             all the talk is dead   20.828571
# 1613       all the flowers in shanghai   20.776636
# 10068  persepolis rising the expanse 7   19.820225

# %%
popular_recs = all_recs[all_recs['book_count'] > 75].sort_values('score', ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

popular_recs[~popular_recs['book_id'].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_730ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T