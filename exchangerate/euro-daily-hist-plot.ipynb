# %%
import pandas as pd
exchange_rates = pd.read_csv('euro-daily-hist_1999_2022.csv',encoding='UTF-8')
exchange_rates.head(5)
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2022-01-10               1.5774           1.9558            6.3969
# 1   2022-01-07               1.5804           1.9558            6.4343
# 2   2022-01-06               1.5778           1.9558            6.4420
# 3   2022-01-05               1.5600           1.9558            6.4146
# 4   2022-01-04               1.5682           1.9558            6.4174
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4327         1.0446                   7.2128              NaN
# 1             1.4374         1.0422                   7.2060              NaN
# 2             1.4451         1.0395                   7.2187              NaN
# 3             1.4399         1.0364                   7.2087              NaN
# 4             1.4382         1.0355                   7.1924              NaN
#
#   [Czech koruna ] [Danish krone ]          ...           [Romanian leu ]  \
# 0          24.357          7.4381          ...                    4.9449
# 1          24.439          7.4380          ...                    4.9451
# 2          24.528          7.4393          ...                    4.9435
# 3          24.581          7.4384          ...                    4.9460
# 4          24.745          7.4378          ...                    4.9481
#
#   [Russian rouble ] [Swedish krona ] [Singapore dollar ] [Slovenian tolar ]  \
# 0           84.9825          10.3038              1.5344                NaN
# 1           85.2980          10.2839              1.5356                NaN
# 2           86.5088          10.3265              1.5388                NaN
# 3           85.7275          10.2545              1.5340                NaN
# 4           84.9202          10.2808              1.5310                NaN
#
#   [Slovak koruna ] [Thai baht ] [Turkish lira ] [US dollar ]  \
# 0              NaN      38.0740         15.7183       1.1318
# 1              NaN      38.0740         15.7206       1.1298
# 2              NaN      37.9620         15.5504       1.1315
# 3              NaN      37.6070         15.2446       1.1319
# 4              NaN      37.5820         15.1384       1.1279
#
#    [South African rand ]
# 0                17.6999
# 1                17.6701
# 2                17.7932
# 3                17.9369
# 4                18.1080
#
# [5 rows x 41 columns]

# %%
exchange_rates.tail(5)
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 5953   1999-01-08               1.8406              NaN               NaN
# 5954   1999-01-07               1.8474              NaN               NaN
# 5955   1999-01-06               1.8820              NaN               NaN
# 5956   1999-01-05               1.8944              NaN               NaN
# 5957   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 5953             1.7643         1.6138                      NaN
# 5954             1.7602         1.6165                      NaN
# 5955             1.7711         1.6116                      NaN
# 5956             1.7965         1.6123                      NaN
# 5957             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]          ...            \
# 5953          0.58187          34.938          7.4433          ...
# 5954          0.58187          34.886          7.4431          ...
# 5955          0.58200          34.850          7.4452          ...
# 5956          0.58230          34.917          7.4495          ...
# 5957          0.58231          35.107          7.4501          ...
#
#      [Romanian leu ] [Russian rouble ] [Swedish krona ] [Singapore dollar ]  \
# 5953          1.3143           27.2075           9.1650              1.9537
# 5954          1.3092           26.9876           9.1800              1.9436
# 5955          1.3168           27.4315           9.3050              1.9699
# 5956          1.3168           26.5876           9.4025              1.9655
# 5957          1.3111           25.2875           9.4696              1.9554
#
#      [Slovenian tolar ] [Slovak koruna ] [Thai baht ] [Turkish lira ]  \
# 5953           188.8400           42.560      42.5590          0.3718
# 5954           188.8000           42.765      42.1678          0.3701
# 5955           188.7000           42.778      42.6949          0.3722
# 5956           188.7750           42.848      42.5048          0.3728
# 5957           189.0450           42.991      42.6799          0.3723
#
#      [US dollar ]  [South African rand ]
# 5953       1.1659                 6.7855
# 5954       1.1632                 6.8283
# 5955       1.1743                 6.7307
# 5956       1.1790                 6.7975
# 5957       1.1789                 6.9358
#
# [5 rows x 41 columns]

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5958 entries, 0 to 5957
# Data columns (total 41 columns):
# Period\Unit:                5958 non-null object
# [Australian dollar ]        5958 non-null object
# [Bulgarian lev ]            5556 non-null object
# [Brazilian real ]           5690 non-null object
# [Canadian dollar ]          5958 non-null object
# [Swiss franc ]              5958 non-null object
# [Chinese yuan renminbi ]    5690 non-null object
# [Cypriot pound ]            2346 non-null object
# [Czech koruna ]             5958 non-null object
# [Danish krone ]             5958 non-null object
# [Estonian kroon ]           3130 non-null object
# [UK pound sterling ]        5958 non-null object
# [Greek drachma ]            520 non-null object
# [Hong Kong dollar ]         5958 non-null object
# [Croatian kuna ]            5690 non-null object
# [Hungarian forint ]         5958 non-null object
# [Indonesian rupiah ]        5958 non-null object
# [Israeli shekel ]           5690 non-null object
# [Indian rupee ]             5690 non-null object
# [Iceland krona ]            3551 non-null float64
# [Japanese yen ]             5958 non-null object
# [Korean won ]               5958 non-null object
# [Lithuanian litas ]         4159 non-null object
# [Latvian lats ]             3904 non-null object
# [Maltese lira ]             2346 non-null object
# [Mexican peso ]             5958 non-null object
# [Malaysian ringgit ]        5958 non-null object
# [Norwegian krone ]          5958 non-null object
# [New Zealand dollar ]       5958 non-null object
# [Philippine peso ]          5958 non-null object
# [Polish zloty ]             5958 non-null object
# [Romanian leu ]             5896 non-null float64
# [Russian rouble ]           5958 non-null object
# [Swedish krona ]            5958 non-null object
# [Singapore dollar ]         5958 non-null object
# [Slovenian tolar ]          2085 non-null object
# [Slovak koruna ]            2608 non-null object
# [Thai baht ]                5958 non-null object
# [Turkish lira ]             5896 non-null float64
# [US dollar ]                5958 non-null object
# [South African rand ]       5958 non-null object
# dtypes: float64(3), object(38)
# memory usage: 1.9+ MB

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                              'Period\\Unit:': 'Time'},
                     inplace=True)
exchange_rates['Time']=pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %%
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy()

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1797     6
# 1.1268     6
# 1.1579     6
# 1.1218     6
# 1.3532     6
# 1.0888     6
# 1.1193     6
# 1.3086     6
# 1.1279     6
# 1.2143     6
# 1.0867     6
# 1.1346     6
# 1.1765     6
# 1.2713     6
# 1.3373     6
# 1.2309     5
# 1.1168     5
# 1.1389     5
# 1.3574     5
# 1.0737     5
# 0.8803     5
# 1.1312     5
# 1.1146     5
# 1.1328     5
# 1.1185     5
# 1.1187     5
#           ..
# 0.8654     1
# 1.2344     1
# 1.1656     1
# 1.1846     1
# 1.4324     1
# 0.9013     1
# 1.1473     1
# 1.0650     1
# 1.4224     1
# 1.1842     1
# 1.2437     1
# 1.4969     1
# 1.1500     1
# 0.9011     1
# 1.2602     1
# 1.0296     1
# 0.8938     1
# 1.2989     1
# 1.1538     1
# 1.5167     1
# 1.0847     1
# 1.4808     1
# 1.2686     1
# 1.5019     1
# 1.5471     1
# 1.4200     1
# 1.0549     1
# 1.0377     1
# 0.9659     1
# 0.8965     1
# Name: US_dollar, Length: 3592, dtype: int64

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5896 entries, 0 to 5957
# Data columns (total 2 columns):
# Time         5896 non-null datetime64[ns]
# US_dollar    5896 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 138.2 KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(euro_to_dollar['Time'],
        euro_to_dollar['US_dollar'])
plt.show()

# %%
euro_to_dollar['rolling_mean']=euro_to_dollar['US_dollar'].rolling(30).mean()

# %%
plt.plot(euro_to_dollar['Time'],
        euro_to_dollar['rolling_mean'])
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.subplot(3,2,1)
plt.plot(euro_to_dollar['Time'],
        euro_to_dollar['US_dollar'])
plt.title('Original values', weight='bold')

for i, rm in zip(range(2,7),[7,30,50,100,365]):
    plt.subplot(3,2,i)
    plt.plot(euro_to_dollar['Time'],
            euro_to_dollar['US_dollar'].rolling(rm).mean())
    plt.title('Rolling Window:{}'.format(str(rm)), weight='bold')
plt.tight_layout()
plt.show()

# %%
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 0    1999-01-04     1.1789           NaN
# 1    1999-01-05     1.1790           NaN
# 2    1999-01-06     1.1743           NaN
# 3    1999-01-07     1.1632           NaN
# 4    1999-01-08     1.1659           NaN
# 5    1999-01-11     1.1569           NaN
# 6    1999-01-12     1.1520           NaN
# 7    1999-01-13     1.1744           NaN
# 8    1999-01-14     1.1653           NaN
# 9    1999-01-15     1.1626           NaN
# 10   1999-01-18     1.1612           NaN
# 11   1999-01-19     1.1616           NaN
# 12   1999-01-20     1.1575           NaN
# 13   1999-01-21     1.1572           NaN
# 14   1999-01-22     1.1567           NaN
# 15   1999-01-25     1.1584           NaN
# 16   1999-01-26     1.1582           NaN
# 17   1999-01-27     1.1529           NaN
# 18   1999-01-28     1.1410           NaN
# 19   1999-01-29     1.1384           NaN
# 20   1999-02-01     1.1338           NaN
# 21   1999-02-02     1.1337           NaN
# 22   1999-02-03     1.1337           NaN
# 23   1999-02-04     1.1263           NaN
# 24   1999-02-05     1.1292           NaN
# 25   1999-02-08     1.1246           NaN
# 26   1999-02-09     1.1333           NaN
# 27   1999-02-10     1.1342           NaN
# 28   1999-02-11     1.1312           NaN
# 29   1999-02-12     1.1244      1.150667
# ...         ...        ...           ...
# 5928 2021-11-30     1.1363      1.146917
# 5929 2021-12-01     1.1314      1.145887
# 5930 2021-12-02     1.1339      1.144893
# 5931 2021-12-03     1.1291      1.143763
# 5932 2021-12-06     1.1287      1.142710
# 5933 2021-12-07     1.1256      1.141503
# 5934 2021-12-08     1.1299      1.140443
# 5935 2021-12-09     1.1311      1.139503
# 5936 2021-12-10     1.1273      1.138263
# 5937 2021-12-13     1.1278      1.137263
# 5938 2021-12-14     1.1309      1.136283
# 5939 2021-12-15     1.1262      1.135230
# 5940 2021-12-16     1.1336      1.134453
# 5941 2021-12-17     1.1330      1.133823
# 5942 2021-12-20     1.1273      1.132803
# 5943 2021-12-21     1.1295      1.131863
# 5944 2021-12-22     1.1301      1.131007
# 5945 2021-12-23     1.1310      1.130507
# 5946 2021-12-24     1.1317      1.130070
# 5947 2021-12-27     1.1312      1.129630
# 5948 2021-12-28     1.1331      1.129507
# 5949 2021-12-29     1.1303      1.129463
# 5950 2021-12-30     1.1334      1.129427
# 5951 2021-12-31     1.1326      1.129610
# 5952 2022-01-03     1.1355      1.129867
# 5953 2022-01-04     1.1279      1.129933
# 5954 2022-01-05     1.1319      1.130310
# 5955 2022-01-06     1.1315      1.130617
# 5956 2022-01-07     1.1298      1.130640
# 5957 2022-01-10     1.1318      1.130780
#
# [5896 rows x 3 columns]

# %% [markdown]
# # Coming Up With an Idea
# * We show how the euro-dollar rate has changed during the coronavirus pandemic. We can show the 2020 data and the 2016-2019 data as a baseline. We can use a line plot.
# * We show how the euro-dollar rate changed during the 2007-2008's financial crisis. We can also show the data for 2016 and 2009 for comparison. We can use a line plot.
# * We show comparatively how the euro-dollar rate changed under the last three US presidents (George W. Bush (2001-2009), Barack Obama (2009-2017), and Donald Trump (2017-2021)). We can use a line plot.

# %% [markdown]
# ## Financial Crisis Example

# %%
financial_crisis_6_9 = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2006) & (euro_to_dollar['Time'].dt.year <=
                                  2009)]
financial_crisis_7_8 = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >=2007) & (euro_to_dollar['Time'].dt.year <=2008)]

# %%
import matplotlib.style as style
style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(8,3))
ax.plot(financial_crisis_6_9['Time'],
       financial_crisis_6_9['rolling_mean'],
       linewidth=1,color='#A6D785')

ax.plot(financial_crisis_7_8['Time'],
       financial_crisis_7_8['rolling_mean'],
       linewidth=1,color='#e23d28')
ax.axvspan(xmin=733112.0,xmax=733302.0, ymin=0.09,
          alpha=0.3, color='grey')

ax.set_xticklabels([])
ax.set_yticklabels([])

x=732272.0
for year in ['2006','2007','2008','2009','2010']:
    ax.text(x,1.13, year, alpha=0.5, fontsize=11)
    x+=365

y=1.193
for rate in ['1.2','1.3','1.4','1.5']:
    ax.text(732172.0, y, rate, alpha=0.5, fontsize=11)
    
ax.text(732172.0, 1.67, "Euro-USD rate peaked at 1.59 during 2007-2008's financial crisis",
       weight='bold')
ax.text(732172.0, 1.63, "Euro-USD exchange rates between 2006 and 2010",
       size=12)

ax.text(732172.0, 1.07, '@DATAQUEST' + ' '*94 + 'Source: European Central Bank',
       color='#f0f0f0', backgroundcolor='#4d4d4d',
       size=10)

ax.grid(alpha=0.5)
plt.show()

# %%
bush_omaba_trump = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2001) &
                                        (euro_to_dollar['Time'].dt.year <= 2021)]

bush = bush_omaba_trump.copy()[bush_omaba_trump['Time'].dt.year <2009
                               ]
obama = bush_omaba_trump.copy()[(bush_omaba_trump['Time'].dt.year >=2009) &
                               (bush_omaba_trump['Time'].dt.year <2017)]
trump = bush_omaba_trump.copy()[(bush_omaba_trump['Time'].dt.year >=2017) &
                               (bush_omaba_trump['Time'].dt.year <2021)
                               ]

# %%
style.use('fivethirtyeight')
plt.figure(figsize=(12,6))
ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)
ax4 = plt.subplot(2,1,2)

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.set_ylim(0.8, 1.7)
    ax.set_yticks([1.0, 1.2, 1.4, 1.6])
    ax.set_yticklabels(['1.0','1.2','1.4','1.6'],
                      alpha=0.3)
    ax.grid(alpha=0.5)
# ax1: bush
ax1.plot(bush['Time'], bush['rolling_mean'],
        color='#BF5FFF')
ax1.set_xticklabels(['','2001','','2003','','2005','','2007','','2009'],
                   alpha=0.3)
ax1.text(731715.0,1.92, 'BUSH', fontsize=18, weight='bold',color = '#BF5FFF')
ax1.text(731216.0, 1.8, '2001-2009', weight='bold',alpha=0.3)

# ax2: omaba
ax2.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax2.set_xticklabels(['','2009','','2011','','2013','','2015','',
                    '2017'], alpha=0.3)
ax2.text(734288.0, 1.92, 'OBAMA', weight='bold', fontsize=18,
        color='#ffa500')
ax2.text(734138.0, 1.8, '(2009-2017)', weight='bold',
        alpha=0.3)

# ax3: trump
ax3.plot(trump['Time'], trump['rolling_mean'],
        color='#00B2EE')
ax3.set_xticklabels(['2017','','2018','','2019','','2020','','2021'],
                   alpha=0.3)
ax3.text(736855.0, 1.92, 'TRUMP', fontsize=18, weight='bold',
        color='#00B2EE')
ax3.text(736745.0, 1.8, '(2017-2021)', weight='bold',
        alpha=0.3)

#ax4: bush-obama-trump
ax4.plot(bush['Time'], bush['rolling_mean'],
        color='#BF5FFF')
ax4.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax4.plot(trump['Time'], trump['rolling_mean'],
        color='#00B2EE')
ax.grid(alpha=0.5)
ax4.set_xticks([])

# Adding a title and a subtitle
ax1.text(730016.0, 2.35, 'EURO-USD rate averaged 1.22 under the last three US presidents',
         fontsize=20, weight='bold')
ax1.text(730016.0, 2.14,'''EURO-USD exchange rates under George W. Bush (2001 - 2009), Barack Obama (2009-2017),
and Donald Trump (2017-2021)''',
        fontsize=16)

ax4.text(729916.0, 0.65, '©DATAQUEST' + ' '*103 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor='#4d4d4d',
        size=14)
plt.show()
